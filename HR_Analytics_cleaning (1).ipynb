# %% [markdown]
# # HR Analytics – Data Cleaning & Preparation
#
# Ce notebook est une version **améliorée et plus professionnelle** du nettoyage des données RH.
#
# Objectifs :
# - Charger et auditer les données
# - Nettoyer les colonnes peu utiles et les incohérences
# - Créer des variables dérivées utiles pour Power BI
# - Préparer une version **analytique** (pour Power BI) et une version **modélisation** (ML possible)
# - Exporter les fichiers propres
#
# > 💡 Place ce notebook dans le **même dossier** que `HR_Analytics.csv`.

# %% [markdown]
# ## 1. Imports & configuration

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 140)

RAW_FILE = 'HR_Analytics.csv'
CLEAN_ANALYTICS_FILE = 'HR_Analytics_clean_analytics.csv'
CLEAN_ML_FILE = 'HR_Analytics_clean_ml.csv'

# %% [markdown]
# ## 2. Chargement du dataset brut

# %%
df = pd.read_csv(RAW_FILE)
print("Shape initiale :", df.shape)
df.head()
# Out:
# Shape initiale : (1480, 38)
#    EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate              Department  DistanceFromHome  Education EducationField  \
# 0  RM297   18    18-25       Yes      Travel_Rarely        230  Research & Development                 3          3  Life Sciences
# 1  RM302   18    18-25        No      Travel_Rarely        812                   Sales                10          3        Medical
# 2  RM458   18    18-25       Yes  Travel_Frequently       1306                   Sales                 5          3      Marketing
# 3  RM728   18    18-25        No         Non-Travel        287  Research & Development                 5          2  Life Sciences
# 4  RM829   18    18-25       Yes         Non-Travel        247  Research & Development                 8          1        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# ...

# %% [markdown]
# ## 3. Audit rapide de la structure des données

# %%
print("\nAperçu des colonnes :")
print(df.columns.tolist())

print("\nInfo :")
df.info()
# Out:
# Aperçu des colonnes :
# ['EmpID', 'Age', 'AgeGroup', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'SalarySlab', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
#
# Info :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1480 entries, 0 to 1479
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmpID                     1480 non-null   object
# ...

# %%
print("Résumé statistique des variables numériques :")
df.describe().T
# Out:
# Résumé statistique des variables numériques :
#                            count          mean          std     min      25%      50%       75%      max
# Age                       1480.0     36.917568     9.128559    18.0    30.00     36.0     43.00     60.0
# DailyRate                 1480.0    801.384459   403.126988   102.0   465.00    800.0   1157.00   1499.0
# DistanceFromHome          1480.0      9.220270     8.131201     1.0     2.00      7.0     14.00     29.0
# Education                 1480.0      2.910811     1.023796     1.0     2.00      3.0      4.00      5.0
# EmployeeCount             1480.0      1.000000     0.000000     1.0     1.00      1.0      1.00      1.0
# EmployeeNumber            1480.0   1031.860811   605.955046     1.0   493.75   1027.5   1568.25   2068.0
# EnvironmentSatisfaction   1480.0      2.724324     1.092579     1.0     2.00      3.0      4.00      4.0
# ...

# %% [markdown]
# ## 4. Analyse des valeurs manquantes

# %%
missing = df.isna().sum().sort_values(ascending=False)
missing[missing > 0]
# Out:
# YearsWithCurrManager    57
# dtype: int64

# %% [markdown]
# ## 5. Doublons

# %%
dup_count = df.duplicated().sum()
print("Nombre de lignes dupliquées :", dup_count)

if dup_count > 0:
    df = df.drop_duplicates().reset_index(drop=True)
    print("Doublons supprimés. Nouvelle shape :", df.shape)
# Out:
# Nombre de lignes dupliquées : 7
# Doublons supprimés. Nouvelle shape : (1473, 38)

# %% [markdown]
# ## 6. Suppression des colonnes peu informatives
#
# Dans beaucoup de jeux de données RH (HR Analytics), les colonnes suivantes sont constantes :
# - `EmployeeCount`
# - `Over18`
# - `StandardHours`
#
# Elles n'apportent pas d'information pour l'analyse, on les retire.

# %%
low_info_cols = []
for col in ['EmployeeCount', 'Over18', 'StandardHours']:
    if col in df.columns and df[col].nunique() <= 1:
        low_info_cols.append(col)

print("Colonnes à faible information :", low_info_cols)
df = df.drop(columns=low_info_cols, errors='ignore')
print("Shape après suppression des colonnes peu informatives :", df.shape)
# Out:
# Colonnes à faible information : ['EmployeeCount', 'Over18', 'StandardHours']
# Shape après suppression des colonnes peu informatives : (1473, 35)

# %% [markdown]
# ## 7. Harmonisation des colonnes catégorielles clés

# %%
# Fonctions utilitaires
def clean_text(s):
    if pd.isna(s):
        return s
    return str(s).strip().replace('_', ' ').title()

if 'Attrition' in df.columns:
    df['Attrition'] = df['Attrition'].astype(str).str.strip().str.title()

for col in ['BusinessTravel', 'Department', 'EducationField', 'JobRole', 'MaritalStatus']:
    if col in df.columns:
        df[col] = df[col].apply(clean_text)

df[['Attrition'] + [c for c in ['BusinessTravel','Department','JobRole'] if c in df.columns]].head()
# Out:
#   Attrition     BusinessTravel              Department                JobRole
# 0       Yes      Travel Rarely  Research & Development  Laboratory Technician
# 1        No      Travel Rarely                   Sales   Sales Representative
# 2       Yes  Travel Frequently                   Sales   Sales Representative
# 3        No         Non-Travel  Research & Development     Research Scientist
# 4       Yes         Non-Travel  Research & Development  Laboratory Technician

# %% [markdown]
# ## 8. Vérification & correction des types de données

# %%
numeric_candidates = ['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate',
                      'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
                      'PercentSalaryHike', 'TotalWorkingYears', 'TrainingTimesLastYear',
                      'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
                      'YearsWithCurrManager']

for col in numeric_candidates:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

df.dtypes.head(20)
# Out:
# EmpID                      object
# Age                         int64
# AgeGroup                   object
# Attrition                  object
# BusinessTravel             object
# DailyRate                   int64
# Department                 object
# DistanceFromHome            int64
# Education                   int64
# EducationField             object
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                     object
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                    object
# JobSatisfaction             int64
# MaritalStatus              object
# MonthlyIncome               int64
# dtype: object

# %% [markdown]
# ## 9. Feature engineering (variables dérivées)
#
# On crée des variables utiles pour Power BI et d'éventuels modèles :
# - `AgeGroup`
# - `SeniorityGroup`
# - `SalaryBand`
# - `IsAttrition` (variable booléenne pour la modélisation)

# %%
# AgeGroup
if 'Age' in df.columns:
    bins_age = [17, 25, 35, 45, 60]
    labels_age = ['18-25', '26-35', '36-45', '46-60']
    df['AgeGroup'] = pd.cut(df['Age'], bins=bins_age, labels=labels_age)

# SeniorityGroup
if 'YearsAtCompany' in df.columns:
    bins_sen = [-1, 2, 5, 10, 40]
    labels_sen = ['0-2 ans', '3-5 ans', '6-10 ans', '10+ ans']
    df['SeniorityGroup'] = pd.cut(df['YearsAtCompany'], bins=bins_sen, labels=labels_sen)

# SalaryBand
if 'MonthlyIncome' in df.columns:
    bins_sal = [0, 3000, 6000, 9000, 20000]
    labels_sal = ['Faible', 'Moyen', 'Élevé', 'Très élevé']
    df['SalaryBand'] = pd.cut(df['MonthlyIncome'], bins=bins_sal, labels=labels_sal)

# IsAttrition (pour ML / stats)
if 'Attrition' in df.columns:
    df['IsAttrition'] = (df['Attrition'] == 'Yes').astype(int)

df[['Age','AgeGroup','YearsAtCompany','SeniorityGroup','MonthlyIncome','SalaryBand','Attrition','IsAttrition']].head()
# Out:
#    Age AgeGroup  YearsAtCompany SeniorityGroup  MonthlyIncome SalaryBand Attrition  IsAttrition
# 0   18    18-25               0        0-2 ans           1420     Faible       Yes            1
# 1   18    18-25               0        0-2 ans           1200     Faible        No            0
# 2   18    18-25               0        0-2 ans           1878     Faible       Yes            1
# 3   18    18-25               0        0-2 ans           1051     Faible        No            0
# 4   18    18-25               0        0-2 ans           1904     Faible       Yes            1

# %% [markdown]
# ## 10. Vérification de l'équilibre de la cible (Attrition)

# %%
if 'Attrition' in df.columns:
    print(df['Attrition'].value_counts(normalize=True).mul(100).round(1))
    print("\nIsAttrition (0/1):\n", df['IsAttrition'].value_counts(normalize=True).mul(100).round(1))
# Out:
# Attrition
# No     83.9
# Yes    16.1
# Name: proportion, dtype: float64
#
# IsAttrition (0/1):
#  IsAttrition
# 0    83.9
# 1    16.1
# Name: proportion, dtype: float64

# %% [markdown]
# ## 11. Aperçu rapide des corrélations numériques

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
corr = df[numeric_cols].corr()
corr['IsAttrition'].sort_values(ascending=False).head(15) if 'IsAttrition' in corr.columns else corr
# Out:
# IsAttrition                 1.000000
# DistanceFromHome            0.077585
# NumCompaniesWorked          0.043469
# MonthlyRate                 0.014647
# PerformanceRating           0.003268
# HourlyRate                 -0.005593
# EmployeeNumber             -0.012076
# PercentSalaryHike          -0.013827
# Education                  -0.030526
# YearsSinceLastPromotion    -0.032487
# RelationshipSatisfaction   -0.045763
# DailyRate                  -0.056809
# TrainingTimesLastYear      -0.059769
# WorkLifeBalance            -0.064221
# JobSatisfaction            -0.103276
# Name: IsAttrition, dtype: float64

# %% [markdown]
# ## 12. Préparation de la version **Analytics** pour Power BI

# %%
df_analytics = df.copy()

# On garde toutes les colonnes utiles, y compris les variables dérivées.
print("Shape df_analytics :", df_analytics.shape)
df_analytics.head()
# Out:
# Shape df_analytics : (1473, 38)
#    EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate              Department  DistanceFromHome  Education EducationField  \
# 0  RM297   18    18-25       Yes      Travel Rarely        230  Research & Development                 3          3  Life Sciences
# 1  RM302   18    18-25        No      Travel Rarely        812                   Sales                10          3        Medical
# 2  RM458   18    18-25       Yes  Travel Frequently       1306                   Sales                 5          3      Marketing
# 3  RM728   18    18-25        No         Non-Travel        287  Research & Development                 5          2  Life Sciences
# 4  RM829   18    18-25       Yes         Non-Travel        247  Research & Development                 8          1        Medical
#
#    EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# ...

# %% [markdown]
# ## 13. Préparation de la version **Modélisation** (ML)

# %%
df_ml = df.copy()

# Exemple : on retire les identifiants directs
for col in ['EmployeeNumber', 'EmployeeID', 'Employee_Id']:
    if col in df_ml.columns:
        df_ml = df_ml.drop(columns=[col])

print("Colonnes df_ml :", len(df_ml.columns))
df_ml.head()
# Out:
# Colonnes df_ml : 37
#    EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate              Department  DistanceFromHome  Education EducationField  \
# 0  RM297   18    18-25       Yes      Travel Rarely        230  Research & Development                 3          3  Life Sciences
# 1  RM302   18    18-25        No      Travel Rarely        812                   Sales                10          3        Medical
# 2  RM458   18    18-25       Yes  Travel Frequently       1306                   Sales                 5          3      Marketing
# 3  RM728   18    18-25        No         Non-Travel        287  Research & Development                 5          2  Life Sciences
# 4  RM829   18    18-25       Yes         Non-Travel        247  Research & Development                 8          1        Medical
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  JobSatisfaction MaritalStatus  \
# ...

# %% [markdown]
# ## 14. Export des fichiers nettoyés

# %%
df_analytics.to_csv(CLEAN_ANALYTICS_FILE, index=False)
print("Fichier analytics exporté :", CLEAN_ANALYTICS_FILE)

df_ml.to_csv(CLEAN_ML_FILE, index=False)
print("Fichier ML exporté :", CLEAN_ML_FILE)
# Out:
# Fichier analytics exporté : HR_Analytics_clean_analytics.csv
# Fichier ML exporté : HR_Analytics_clean_ml.csv

# %% [markdown]
# ## 15. Résumé
#
# Ce notebook :
# - nettoie les colonnes redondantes et les incohérences texte
# - harmonise les types
# - crée des variables dérivées utiles (`AgeGroup`, `SeniorityGroup`, `SalaryBand`, `IsAttrition`)
# - prépare **2 fichiers** :
#   - `HR_Analytics_clean_analytics.csv` → pour Power BI
#   - `HR_Analytics_clean_ml.csv` → pour d'éventuelles analyses statistiques ou modèles de prédiction
#
# Tu peux maintenant :
# - connecter Power BI au fichier `HR_Analytics_clean_analytics.csv`
# - ou utiliser `HR_Analytics_clean_ml.csv` dans un autre notebook pour la modélisation.
